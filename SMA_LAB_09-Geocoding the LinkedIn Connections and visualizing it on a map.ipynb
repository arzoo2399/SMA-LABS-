# %% [markdown]
# # <center> Lab 9. Geocoding the LinkedIn Connections and visualising it on a map </center>
#
# ### 205229103
#
# ### Arzoo Sah

# %% [markdown]
# In this lab you need to access your LinkedIn Connections and geocode the companies of the connections and visualise it on a map
#
# ### 1.	Retrieve the Connections data of your LinkedIn Profile from the previous lab and read it as a csv file using pandas module

# %%
import os
import csv

CSV_FILE = os.path.join('Connections.csv')

csvReader = csv.DictReader(open(CSV_FILE), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]

# %%
contacts
# Out:
# [{'First Name': 'DIVYAA ',
#   'Last Name': 'LAKSHMI AS',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '16-Sep-21'},
#  {'First Name': 'LALITH',
#   'Last Name': 'AKASH',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '11-Sep-21'},
#  {'First Name': 'Frastlin',
#   'Last Name': 'J',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '02-Sep-21'},
#  {'First Name': 'BHARATH',
#   'Last Name': 'S',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '25-Aug-21'},
#  {'First Name': 'Samir',
#   'Last Name': 'Mendhe',
#   'Email Address': '',
#   'Company': 'ELEATION',
#   'Position': 'Project Intern In Design',
#   'Connected On': '24-Aug-21'},
#  {'First Name': 'HARIKESH',
#   'Last Name': '.',
#   'Email Address': '',
#   'Company': 'Chegg Inc.',
#   'Position': 'Q&A Expert',
#   'Connected On': '09-Aug-21'},
#  {'First Name': 'Rajamalliga',
#   'Last Name': 'Sundar',
#   'Email Address': '',
#   'Company': 'AASHMAN FOUNDATION',
#   'Position': 'Human Resources Intern',
#   'Connected On': '08-Aug-21'},
#  {'First Name': 'Malleeswari',
#   'Last Name': 'G',
#   'Email Address': '',
#   'Company': 'LetsGrowMore',
#   'Position': 'Data Science Intern',
#   'Connected On': '21-Jul-21'},
#  {'First Name': 'Maheshvaran',
#   'Last Name': 'S',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '18-Jul-21'},
#  {'First Name': 'Keerthana',
#   'Last Name': 'S',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '10-Jul-21'},
#  {'First Name': 'Mahalakshmi',
#   'Last Name': 'S',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': 'Data Science and Bussiness Analytics intern at  The Sparks Foundation ',
#   'Connected On': '20-Jun-21'},
#  {'First Name': 'Howsik',
#   'Last Name': 'T',
#   'Email Address': '',
#   'Company': 'Digiit Business Services',
#   'Position': 'Graphic Web Designer',
#   'Connected On': '20-Jun-21'},
#  {'First Name': 'Deepak',
#   'Last Name': 'R',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': ' Data Science and Business Analystics Intern ',
#   'Connected On': '20-Jun-21'},
#  {'First Name': 'Viveka',
#   'Last Name': 'Balaji',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': 'Data science and business analytics intern',
#   'Connected On': '20-Jun-21'},
#  {'First Name': 'Mohamed',
#   'Last Name': 'Sahim',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': 'Data Science and Business Analytics',
#   'Connected On': '15-Jun-21'},
#  {'First Name': 'Hariharasudhan',
#   'Last Name': 'D',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '04-Jun-21'},
#  {'First Name': 'Reshma',
#   'Last Name': 'R S',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': 'Data Science and Business Analytics Intern',
#   'Connected On': '04-Jun-21'},
#  {'First Name': 'Bhargavi',
#   'Last Name': 'Srinivasan',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '16-Apr-21'},
#  {'First Name': 'Keerthana',
#   'Last Name': 'V',
#   'Email Address': '',
#   'Company': 'PlaceXP VITC',
#   'Position': 'Content Writer',
#   'Connected On': '27-Jan-21'},
#  {'First Name': 'Ashish',
#   'Last Name': 'Shah',
#   'Email Address': '',
#   'Company': 'Radite Energy',
#   'Position': 'Design Engineer',
#   'Connected On': '02-Jan-21'}]

# %% [markdown]
# ### 2.Apply transformation to the Company feature by removing the company related suffixes

# %%
from prettytable import PrettyTable 
from collections import Counter
from operator import itemgetter


transforms = [(', Inc.', ''), (', Inc', ''), (', LLC', ''), (', LLP', ''),
               (' LLC', ''), (' Inc.', ''), (' Inc', '')]

companies = [c['Company'].strip() for c in contacts if c['Company'].strip() != '']

for i, _ in enumerate(companies):
    for transform in transforms:
        companies[i] = companies[i].replace(*transform)

pt = PrettyTable(field_names=['Company', 'Freq'])
pt.align = 'l'
c = Counter(companies)

[pt.add_row([company, freq]) for (company, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) if freq > 0]

print(pt)
# Out:
# +--------------------------+------+
# | Company                  | Freq |
# +--------------------------+------+
# | The Sparks Foundation    | 5    |
# | ELEATION                 | 1    |
# | Chegg                    | 1    |
# | AASHMAN FOUNDATION       | 1    |
# | LetsGrowMore             | 1    |
# | Digiit Business Services | 1    |
# | PlaceXP VITC             | 1    |
# | Radite Energy            | 1    |
# +--------------------------+------+

# %%
transforms = [
    ('Sr.', 'Senior'),
    ('Sr', 'Senior'),
    ('Jr.', 'Junior'),
    ('Jr', 'Junior'),
    ('CEO', 'Chief Executive Officer'),
    ('COO', 'Chief Operating Officer'),
    ('CTO', 'Chief Technology Officer'),
    ('CFO', 'Chief Finance Officer'),
    ('VP', 'Vice President'),
    ]


titles = []
for contact in contacts:
    titles.extend([t.strip() for t in contact['Position'].split('/')
                  if contact['Position'].strip() != ''])

# Replace common/known abbreviations

for i, _ in enumerate(titles):
    for transform in transforms:
        titles[i] = titles[i].replace(*transform)

# Print out a table of titles sorted by frequency

pt = PrettyTable(field_names=['Job Title', 'Freq'])
pt.align = 'l'
c = Counter(titles)
[pt.add_row([title, freq]) 
 for (title, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1]
print(pt)

# Print out a table of tokens sorted by frequency

tokens = []
for title in titles:
    tokens.extend([t.strip(',') for t in title.split()])
pt = PrettyTable(field_names=['Token', 'Freq'])
pt.align = 'l'
c = Counter(tokens)
[pt.add_row([token, freq]) 
 for (token, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1 and len(token) > 1]
print(pt)
# Out:
# +-----------+------+
# | Job Title | Freq |
# +-----------+------+
# +-----------+------+
# +-----------+------+
# | Token     | Freq |
# +-----------+------+
# | Data      | 6    |
# | Intern    | 5    |
# | Science   | 5    |
# | and       | 5    |
# | Analytics | 3    |
# | Business  | 3    |
# | Design    | 2    |
# | intern    | 2    |
# +-----------+------+

# %% [markdown]
# ### 3.	Geocode the companies and get the latitude longitude values of the organisations using opencage module

# %%
# !pip install opencage
# Out:
# Requirement already satisfied: opencage in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (2.0.0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from opencage) (1.11.1)
# Requirement already satisfied: pyopenssl>=0.15.1 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from opencage) (20.0.1)
# Requirement already satisfied: Requests>=2.2.0 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from opencage) (2.25.1)
# Requirement already satisfied: cryptography>=3.2 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from pyopenssl>=0.15.1->opencage) (3.4.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from pyopenssl>=0.15.1->opencage) (1.15.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from cryptography>=3.2->pyopenssl>=0.15.1->opencage) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from cffi>=1.12->cryptography>=3.2->pyopenssl>=0.15.1->opencage) (2.20)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from Requests>=2.2.0->opencage) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from Requests>=2.2.0->opencage) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from Requests>=2.2.0->opencage) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from Requests>=2.2.0->opencage) (1.26.3)

# %%
from opencage.geocoder import OpenCageGeocode 
key = '667503773cd74415878dcf233841c9fc'
geocoder = OpenCageGeocode(key)

query = "82 Clerkenwell Road, London"
result = geocoder.geocode(query)

# %%
result
# Out:
# [{'annotations': {'DMS': {'lat': "51° 31' 21.62712'' N",
#     'lng': "0° 6' 9.08568'' E"},
#    'MGRS': '30UYC0100211931',
#    'Maidenhead': 'IO91wm75qk',
#    'Mercator': {'x': -11412.901, 'y': 6680802.847},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=97508195#map=16/51.52267/-0.10252',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=16/51.52267/-0.10252&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=51.52267&mlon=-0.10252#map=16/51.52267/-0.10252'},
#    'UN_M49': {'regions': {'EUROPE': '150',
#      'GB': '826',
#      'NORTHERN_EUROPE': '154',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 44,
#    'currency': {'alternate_symbols': [],
#     'decimal_mark': '.',
#     'html_entity': '&#x00A3;',
#     'iso_code': 'GBP',
#     'iso_numeric': '826',
#     'name': 'British Pound',
#     'smallest_denomination': 1,
#     'subunit': 'Penny',
#     'subunit_to_unit': 100,
#     'symbol': '£',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇬🇧',
#    'geohash': 'gcpvjemm748dvuqce1sf',
#    'qibla': 119.03,
#    'roadinfo': {'drive_on': 'left',
#     'road': 'Clerkenwell Road',
#     'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1632030180,
#      'astronomical': 1632023280,
#      'civil': 1632028140,
#      'nautical': 1632025800},
#     'set': {'apparent': 1632074640,
#      'astronomical': 1632081540,
#      'civil': 1632076680,
#      'nautical': 1632079020}},
#    'timezone': {'name': 'Europe/London',
#     'now_in_dst': 1,
#     'offset_sec': 3600,
#     'offset_string': '+0100',
#     'short_name': 'BST'},
#    'what3words': {'words': 'grew.tens.club'}},
#   'bounds': {'northeast': {'lat': 51.5227613, 'lng': -0.1024124},
#    'southwest': {'lat': 51.5226092, 'lng': -0.1026351}},
#   'components': {'ISO_3166-1_alpha-2': 'GB',
#    'ISO_3166-1_alpha-3': 'GBR',
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'London',
#    'city_district': 'London Borough of Islington',
#    'continent': 'Europe',
#    'country': 'United Kingdom',
#    'country_code': 'gb',
#    'house_number': '82',
#    'neighbourhood': 'Farringdon',
#    'postcode': 'EC1M 5RF',
#    'road': 'Clerkenwell Road',
#    'state': 'England',
#    'state_code': 'ENG',
#    'state_district': 'Greater London',
#    'suburb': 'Clerkenwell'},
#   'confidence': 10,
#   'formatted': '82 Clerkenwell Road, London, EC1M 5RF, United Kingdom',
#   'geometry': {'lat': 51.5226742, 'lng': -0.1025238}},
#  {'annotations': {'DMS': {'lat': "51° 31' 17.41296'' N",
#     'lng': "0° 6' 47.90916'' E"},
#    'MGRS': '30UYC0025911771',
#    'Maidenhead': 'IO91wm65jd',
#    'Mercator': {'x': -12613.4, 'y': 6680593.97},
#    'OSM': {'note_url': 'https://www.openstreetmap.org/note/new#map=16/51.52150/-0.11331&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=51.52150&mlon=-0.11331#map=16/51.52150/-0.11331'},
#    'UN_M49': {'regions': {'EUROPE': '150',
#      'GB': '826',
#      'NORTHERN_EUROPE': '154',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 44,
#    'currency': {'alternate_symbols': [],
#     'decimal_mark': '.',
#     'html_entity': '&#x00A3;',
#     'iso_code': 'GBP',
#     'iso_numeric': '826',
#     'name': 'British Pound',
#     'smallest_denomination': 1,
#     'subunit': 'Penny',
#     'subunit_to_unit': 100,
#     'symbol': '£',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇬🇧',
#    'geohash': 'gcpvj7jqx8rk73j8354w',
#    'qibla': 119.02,
#    'roadinfo': {'drive_on': 'left',
#     'road': 'Clerkenwell Road',
#     'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1632030180,
#      'astronomical': 1632023280,
#      'civil': 1632028200,
#      'nautical': 1632025800},
#     'set': {'apparent': 1632074640,
#      'astronomical': 1632081540,
#      'civil': 1632076680,
#      'nautical': 1632079020}},
#    'timezone': {'name': 'Europe/London',
#     'now_in_dst': 1,
#     'offset_sec': 3600,
#     'offset_string': '+0100',
#     'short_name': 'BST'},
#    'what3words': {'words': 'plug.relax.words'}},
#   'components': {'ISO_3166-1_alpha-2': 'GB',
#    'ISO_3166-1_alpha-3': 'GBR',
#    '_category': 'building',
#    '_type': 'building',
#    'continent': 'Europe',
#    'country': 'United Kingdom',
#    'country_code': 'gb',
#    'house_number': '82',
#    'road': 'Clerkenwell Road',
#    'town': 'London'},
#   'confidence': 10,
#   'formatted': '82 Clerkenwell Road, London, United Kingdom',
#   'geometry': {'lat': 51.5215036, 'lng': -0.1133081}},
#  {'annotations': {'DMS': {'lat': "51° 30' 30.70800'' N",
#     'lng': "0° 7' 32.66400'' E"},
#    'MGRS': '30UXC9945410295',
#    'Maidenhead': 'IO91wm42vb',
#    'Mercator': {'x': -13997.313, 'y': 6678279.278},
#    'OSM': {'note_url': 'https://www.openstreetmap.org/note/new#map=16/51.50853/-0.12574&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=51.50853&mlon=-0.12574#map=16/51.50853/-0.12574'},
#    'UN_M49': {'regions': {'EUROPE': '150',
#      'GB': '826',
#      'NORTHERN_EUROPE': '154',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 44,
#    'currency': {'alternate_symbols': [],
#     'decimal_mark': '.',
#     'html_entity': '&#x00A3;',
#     'iso_code': 'GBP',
#     'iso_numeric': '826',
#     'name': 'British Pound',
#     'smallest_denomination': 1,
#     'subunit': 'Penny',
#     'subunit_to_unit': 100,
#     'symbol': '£',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇬🇧',
#    'geohash': 'gcpvj0u6yjcmwxz8bn43',
#    'qibla': 118.99,
#    'roadinfo': {'drive_on': 'left', 'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1632030180,
#      'astronomical': 1632023280,
#      'civil': 1632028200,
#      'nautical': 1632025800},
#     'set': {'apparent': 1632074640,
#      'astronomical': 1632081540,
#      'civil': 1632076680,
#      'nautical': 1632079020}},
#    'timezone': {'name': 'Europe/London',
#     'now_in_dst': 1,
#     'offset_sec': 3600,
#     'offset_string': '+0100',
#     'short_name': 'BST'},
#    'what3words': {'words': 'thing.then.link'}},
#   'bounds': {'northeast': {'lat': 51.6913847, 'lng': 0.3356759},
#    'southwest': {'lat': 51.2862242, 'lng': -0.5088138}},
#   'components': {'ISO_3166-1_alpha-2': 'GB',
#    'ISO_3166-1_alpha-3': 'GBR',
#    '_category': 'place',
#    '_type': 'city',
#    'continent': 'Europe',
#    'country': 'United Kingdom',
#    'country_code': 'gb',
#    'county': 'Greater London',
#    'state': 'England',
#    'state_code': 'ENG',
#    'town': 'London'},
#   'confidence': 1,
#   'formatted': 'London, United Kingdom',
#   'geometry': {'lat': 51.50853, 'lng': -0.12574}}]

# %% [markdown]
# ### 4.	Visualise the connections on a map and observe your network

# %%
from opencage.geocoder import OpenCageGeocode
key = "667503773cd74415878dcf233841c9fc"
geocoder = OpenCageGeocode(key)
address='First Name'
result = geocoder.geocode(address, no_annotations="1")  
result[0]['geometry']
# Out:
# {'lat': 52.5477127, 'lng': -1.935611}

# %%
import pandas as pd
data=pd.read_csv('Connections.csv')
data.head()
# Out:
#   First Name   Last Name  Email Address   Company                  Position  \
# 0    DIVYAA   LAKSHMI AS            NaN       NaN                       NaN
# 1     LALITH       AKASH            NaN       NaN                       NaN
# 2   Frastlin           J            NaN       NaN                       NaN
# 3    BHARATH           S            NaN       NaN                       NaN
# 4      Samir      Mendhe            NaN  ELEATION  Project Intern In Design
#
#   Connected On
# 0    16-Sep-21
# 1    11-Sep-21
# 2    02-Sep-21
# 3    25-Aug-21
# 4    24-Aug-21

# %%
addresses = data["Connected On"].values.tolist()
key = "667503773cd74415878dcf233841c9fc"
geocoder = OpenCageGeocode(key)
latitudes = []
longitudes = []
for address in addresses: 
    result = geocoder.geocode(address, no_annotations="1")  
    
    if result and len(result):  
        longitude = result[0]["geometry"]["lng"]  
        latitude = result[0]["geometry"]["lat"] 
    else:  
        longitude = "N/A"  
        latitude = "N/A"     
    
    latitudes.append(latitude) 
    longitudes.append(longitude)

# %%
data["latitudes"] = latitudes
data["longitudes"] = longitudes
data.tail()
# Out:
#         First Name   Last Name  Email Address                Company  \
# 15  Hariharasudhan           D            NaN                    NaN
# 16          Reshma         R S            NaN  The Sparks Foundation
# 17        Bhargavi  Srinivasan            NaN                    NaN
# 18       Keerthana           V            NaN           PlaceXP VITC
# 19          Ashish        Shah            NaN          Radite Energy
#
#                                       Position Connected On  latitudes  \
# 15                                         NaN    04-Jun-21  -4.586000
# 16  Data Science and Business Analytics Intern    04-Jun-21  -4.586000
# 17                                         NaN    16-Apr-21  23.117654
# 18                              Content Writer    27-Jan-21  58.943073
# 19                             Design Engineer    02-Jan-21  58.943073
#
#     longitudes
# 15  -44.605606
# 16  -44.605606
# 17   81.696099
# 18    5.689091
# 19    5.689091

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.12.1-py2.py3-none-any.whl (94 kB)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from folium) (1.19.5)
# Requirement already satisfied: requests in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from folium) (2.25.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from requests->folium) (1.26.3)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from requests->folium) (2020.12.5)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.12.1

# %%
import folium
from folium.plugins import FastMarkerCluster

# %%
folium_map= folium.Map(location=[40.124350,-74.051081],zoom_start=4.4,control_scale=True)
FastMarkerCluster(data[['latitudes', 'longitudes']].values.tolist()).add_to(folium_map)
folium.LayerControl().add_to(folium_map) 
for row in data.iterrows():
    row=row[1]
    folium.CircleMarker(location=(row["latitudes"],
                                  row["longitudes"]),
                        radius= 10,
                        color="#007849",
                        popup=row['Company'],
                        fill=False).add_to(folium_map)
    
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e359818af37340019fc82123910f0a3d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e359818af37340019fc82123910f0a3d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...
