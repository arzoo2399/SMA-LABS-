# %% [markdown]
# # <center>Lab 7. Calculating centrality measures and creating an interest graph for a Github user</center>

# %%
# !pip3 install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (2.5.1)
# Requirement already satisfied: decorator<5,>=4.3 in c:\users\arzoo sah\anaconda3\envs\notebook\lib\site-packages (from networkx) (4.4.2)

# %%
from github import Github
import networkx as nx 
from operator import itemgetter
from IPython.display import HTML
from IPython.core.display import display
import sys
from collections import Counter
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ## 1. Calculate the degree, betweenness, and closeness centrality measures of a krackhardt kite graph

# %%
kkg = nx.generators.small.krackhardt_kite_graph()

display(HTML('<img src="files/resources//kite-graph.png" width="400px">'))

print("Degree Centrality")
print (sorted(nx.degree_centrality(kkg).items(), 
             key=itemgetter(1), reverse=True))

print("Betweenness Centrality")
print(sorted(nx.betweenness_centrality(kkg).items(), 
             key=itemgetter(1), reverse=True))

print("Closeness Centrality")
print(sorted(nx.closeness_centrality(kkg).items(), 
             key=itemgetter(1), reverse=True))
# Out:
# <img src="files/resources//kite-graph.png" width="400px">
# Degree Centrality
# [(3, 0.6666666666666666), (5, 0.5555555555555556), (6, 0.5555555555555556), (0, 0.4444444444444444), (1, 0.4444444444444444), (2, 0.3333333333333333), (4, 0.3333333333333333), (7, 0.3333333333333333), (8, 0.2222222222222222), (9, 0.1111111111111111)]
# Betweenness Centrality
# [(7, 0.38888888888888884), (5, 0.23148148148148148), (6, 0.23148148148148148), (8, 0.2222222222222222), (3, 0.10185185185185183), (0, 0.023148148148148143), (1, 0.023148148148148143), (2, 0.0), (4, 0.0), (9, 0.0)]
# Closeness Centrality
# [(5, 0.6428571428571429), (6, 0.6428571428571429), (3, 0.6), (7, 0.6), (0, 0.5294117647058824), (1, 0.5294117647058824), (2, 0.5), (4, 0.5), (8, 0.42857142857142855), (9, 0.3103448275862069)]

# %%
nx.draw_networkx(kkg)

# %% [markdown]
# ## 2. Create an interest graph of a github user by adding ‘follows’ as edges

# %% [markdown]
# #### a. Find the stargazers of a github user

# %%
ACCESS_TOKEN = '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'
USER = 'dphi-official'
REPO = 'Machine_Learning_Bootcamp' #REPO = 'Mining-the-Social-Web-2nd-Edition
client = Github(ACCESS_TOKEN, per_page=100)
user = client.get_user(USER)
repo = user.get_repo(REPO)

# %%
g = nx.DiGraph()
g.add_node(repo.name + '(repo)', type='repo', lang=repo.language, owner=user.login)
stargazers = [ s for s in repo.get_stargazers()]
print("Number of stargazers", len(stargazers))
for sg in stargazers:
    g.add_node(sg.login + '(user)', type='user')
    g.add_edge(sg.login + '(user)', repo.name + '(repo)', type='gazes')
# Out:
# Number of stargazers 67

# %% [markdown]
# #### b. Create a graph of the star gazers using the networkx package and get the information about the graph

# %%
for i, sg in enumerate(stargazers):
    try:
        for follower in sg.get_followers():
            if follower.login + '(user)' in g:
                g.add_edge(follower.login + '(user)', sg.login + '(user)',type='follows')
    except Exception as e:
        print("Encountered an error fetching followers for", sg.login, "Skipping.", file=sys.stderr)
        print(e, file=sys.stderr)
        
    print("Processed", i+1," stargazers.")

    print("Num nodes ",g.number_of_nodes())

    print("edges in graph", g.number_of_edges())

    print("Rate limit remaining", client.rate_limiting)
# Out:
# Processed 1  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4996, 5000)
# Processed 2  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4995, 5000)
# Processed 3  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4994, 5000)
# Processed 4  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4993, 5000)
# Processed 5  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4992, 5000)
# Processed 6  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4991, 5000)
# Processed 7  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4990, 5000)
# Processed 8  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4989, 5000)
# Processed 9  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4988, 5000)
# Processed 10  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4987, 5000)
# Processed 11  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4986, 5000)
# Processed 12  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4985, 5000)
# Processed 13  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4984, 5000)
# Processed 14  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4983, 5000)
# Processed 15  stargazers.
# Num nodes  68
# edges in graph 67
# Rate limit remaining (4982, 5000)
# Processed 16  stargazers.
# Num nodes  68
# edges in graph 68
# Rate limit remaining (4981, 5000)
# Processed 17  stargazers.
# Num nodes  68
# edges in graph 68
# Rate limit remaining (4980, 5000)
# Processed 18  stargazers.
# Num nodes  68
# edges in graph 68
# Rate limit remaining (4979, 5000)
# Processed 19  stargazers.
# Num nodes  68
# edges in graph 68
# Rate limit remaining (4978, 5000)
# Processed 20  stargazers.
# Num nodes  68
# edges in graph 68
# Rate limit remaining (4977, 5000)
# Processed 21  stargazers.
# Num nodes  68
# edges in graph 68
# Rate limit remaining (4976, 5000)
# Processed 22  stargazers.
# Num nodes  68
# edges in graph 68
# Rate limit remaining (4975, 5000)
# Processed 23  stargazers.
# Num nodes  68
# edges in graph 68
# Rate limit remaining (4974, 5000)
# Processed 24  stargazers.
# Num nodes  68
# edges in graph 68
# Rate limit remaining (4973, 5000)
# Processed 25  stargazers.
# Num nodes  68
# edges in graph 68
# Rate limit remaining (4971, 5000)
# Processed 26  stargazers.
# Num nodes  68
# edges in graph 68
# Rate limit remaining (4970, 5000)
# Processed 27  stargazers.
# Num nodes  68
# edges in graph 69
# Rate limit remaining (4969, 5000)
# Processed 28  stargazers.
# Num nodes  68
# edges in graph 70
# Rate limit remaining (4968, 5000)
# Processed 29  stargazers.
# Num nodes  68
# edges in graph 70
# Rate limit remaining (4967, 5000)
# Processed 30  stargazers.
# Num nodes  68
# edges in graph 70
# Rate limit remaining (4966, 5000)
# Processed 31  stargazers.
# Num nodes  68
# edges in graph 70
# Rate limit remaining (4965, 5000)
# Processed 32  stargazers.
# Num nodes  68
# edges in graph 70
# Rate limit remaining (4964, 5000)
# Processed 33  stargazers.
# Num nodes  68
# edges in graph 70
# Rate limit remaining (4963, 5000)
# Processed 34  stargazers.
# Num nodes  68
# edges in graph 70
# Rate limit remaining (4962, 5000)
# Processed 35  stargazers.
# Num nodes  68
# edges in graph 73
# Rate limit remaining (4960, 5000)
# Processed 36  stargazers.
# Num nodes  68
# edges in graph 74
# Rate limit remaining (4946, 5000)
# Processed 37  stargazers.
# Num nodes  68
# edges in graph 74
# Rate limit remaining (4945, 5000)
# Processed 38  stargazers.
# Num nodes  68
# edges in graph 74
# Rate limit remaining (4944, 5000)
# Processed 39  stargazers.
# Num nodes  68
# edges in graph 76
# Rate limit remaining (4942, 5000)
# Processed 40  stargazers.
# Num nodes  68
# edges in graph 76
# Rate limit remaining (4941, 5000)
# Processed 41  stargazers.
# Num nodes  68
# edges in graph 77
# Rate limit remaining (4940, 5000)
# Processed 42  stargazers.
# Num nodes  68
# edges in graph 77
# Rate limit remaining (4939, 5000)
# Processed 43  stargazers.
# Num nodes  68
# edges in graph 77
# Rate limit remaining (4938, 5000)
# Processed 44  stargazers.
# Num nodes  68
# edges in graph 80
# Rate limit remaining (4937, 5000)
# Processed 45  stargazers.
# Num nodes  68
# edges in graph 80
# Rate limit remaining (4936, 5000)
# Processed 46  stargazers.
# Num nodes  68
# edges in graph 80
# Rate limit remaining (4935, 5000)
# Processed 47  stargazers.
# Num nodes  68
# edges in graph 80
# Rate limit remaining (4934, 5000)
# Processed 48  stargazers.
# Num nodes  68
# edges in graph 81
# Rate limit remaining (4933, 5000)
# Processed 49  stargazers.
# Num nodes  68
# edges in graph 81
# Rate limit remaining (4932, 5000)
# Processed 50  stargazers.
# Num nodes  68
# edges in graph 81
# Rate limit remaining (4931, 5000)
# Processed 51  stargazers.
# Num nodes  68
# edges in graph 81
# Rate limit remaining (4930, 5000)
# Processed 52  stargazers.
# Num nodes  68
# edges in graph 81
# Rate limit remaining (4929, 5000)
# Processed 53  stargazers.
# Num nodes  68
# edges in graph 82
# Rate limit remaining (4928, 5000)
# Processed 54  stargazers.
# Num nodes  68
# edges in graph 82
# Rate limit remaining (4927, 5000)
# Processed 55  stargazers.
# Num nodes  68
# edges in graph 82
# Rate limit remaining (4926, 5000)
# Processed 56  stargazers.
# Num nodes  68
# edges in graph 83
# Rate limit remaining (4925, 5000)
# Processed 57  stargazers.
# Num nodes  68
# edges in graph 83
# Rate limit remaining (4924, 5000)
# Processed 58  stargazers.
# Num nodes  68
# edges in graph 83
# Rate limit remaining (4923, 5000)
# Processed 59  stargazers.
# Num nodes  68
# edges in graph 83
# Rate limit remaining (4922, 5000)
# Processed 60  stargazers.
# Num nodes  68
# edges in graph 83
# Rate limit remaining (4921, 5000)
# Processed 61  stargazers.
# Num nodes  68
# edges in graph 83
# Rate limit remaining (4920, 5000)
# Processed 62  stargazers.
# Num nodes  68
# edges in graph 83
# Rate limit remaining (4919, 5000)
# Processed 63  stargazers.
# Num nodes  68
# edges in graph 84
# Rate limit remaining (4918, 5000)
# Processed 64  stargazers.
# Num nodes  68
# edges in graph 86
# Rate limit remaining (4917, 5000)
# Processed 65  stargazers.
# Num nodes  68
# edges in graph 88
# Rate limit remaining (4916, 5000)
# Processed 66  stargazers.
# Num nodes  68
# edges in graph 88
# Rate limit remaining (4915, 5000)
# Processed 67  stargazers.
# Num nodes  68
# edges in graph 88
# Rate limit remaining (4914, 5000)

# %%
nx.draw(g)

# %% [markdown]
# #### c. Add "follows" edges between stargazers in the graph if any relationships exist

# %% [markdown]
# ## 3. Explore the graph with the updates ‘follows’ edges

# %% [markdown]
# #### a. Get the information about the updated graph

# %%
nx.info(g)
# Out:
# 'Name: \nType: DiGraph\nNumber of nodes: 68\nNumber of edges: 88\nAverage in degree:   1.2941\nAverage out degree:   1.2941'

# %% [markdown]
# ##### b. Find the number of ‘follow’ edges

# %%
print(len([e for e in g.edges(data=True) if e[2]['type'] == 'follows']))
# Out:
# 21

# %% [markdown]
# ##### c. Find the number of popular users and the top 10 users

# %%
c = Counter([e[1] for e in g.edges(data=True) if e[2]['type'] == 'follows'])
popular_users = [ (u, f) for (u, f) in c.most_common() if f > 1 ]
print("Number of popular users", len(popular_users))
print("Top 10 popular users:", popular_users[:10])
# Out:
# Number of popular users 5
# Top 10 popular users: [('rowers7(user)', 3), ('semanurkps(user)', 3), ('deepchatterjeevns(user)', 2), ('KC2016(user)', 2), ('lillaszulyovszky(user)', 2)]

# %% [markdown]
# #### d. Remove the super node from the graph and calculate the centrality measures

# %%
h = g.copy()
h.remove_node('Machine_Learning_Bootcamp(repo)')

# %% [markdown]
# ## 4. Visualise the created interest graph

# %% [markdown]
# #### a. Create a subgraph from the original interest graph- select the user nodes and get the information about the updated graph

# %%
mtsw_users = [n for n in g if g.nodes[n]['type'] == 'user']
h = g.subgraph(mtsw_users)
print("Stats on the extracted subgraph")
print(nx.info(h))
# Out:
# Stats on the extracted subgraph
# Name:
# Type: DiGraph
# Number of nodes: 67
# Number of edges: 21
# Average in degree:   0.3134
# Average out degree:   0.3134

# %% [markdown]
# #### b. Visualise the extracted graph using matplotlib and networkx

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111)
labels = dict([(n, n.split('(user)')[0]) for n in h.nodes()])
nx.draw(h, pos=nx.spring_layout(h), arrows=False, ax=ax, node_size=50,
edge_color='#aaaaaa', alpha=0.8, labels=labels, font_size=8)
